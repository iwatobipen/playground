# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import torch
import torch.nn.functional as F
from torch.nn import Linear
from torch.nn import BatchNorm1d
from torch.utils.data import Dataset
from torch_geometric.nn import GCNConv
from torch_geometric.nn import ChebConv
from torch_geometric.nn import global_add_pool, global_mean_pool
from torch_geometric.data import DataLoader
from torch_scatter import scatter_mean
import mol2graph
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# %%
plt.style.use("ggplot")

# %%
train_mols = [m for m in Chem.SDMolSupplier('solubility.train.sdf')]
test_mols = [m for m in Chem.SDMolSupplier('solubility.test.sdf')]
sol_cls_dict = {'(A) low':0, '(B) medium':1, '(C) high':2}
print(len(train_mols), len(test_mols))
print(train_mols[0].GetPropsAsDict())
# Out:
# 1025 257
# {'ID': 1, 'NAME': 'n-pentane', 'SOL': -3.18, 'SOL_classification': '(A) low', 'smiles': 'CCCCC'}

# %%
Draw.MolsToGridImage(train_mols[:40], molsPerRow=10)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x800 at 0x10C573EF0>

# %%
Draw.MolsToGridImage(test_mols[:40], molsPerRow=10)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x800 at 0x1A27F73940>

# %%
train_X = [mol2graph.mol2vec(m) for m in train_mols]
for i, data in enumerate(train_X):
    y = sol_cls_dict[train_mols[i].GetProp('SOL_classification')]
    data.y = torch.tensor([y], dtype=torch.long)

test_X = [mol2graph.mol2vec(m) for m in test_mols]
for i, data in enumerate(test_X):
    y = sol_cls_dict[test_mols[i].GetProp('SOL_classification')]
    data.y = torch.tensor([y], dtype=torch.long)

# %%
train_loader = DataLoader(train_X, batch_size=64, shuffle=True, drop_last=True)
test_loader = DataLoader(test_X, batch_size=64, shuffle=True, drop_last=True)

# %%
n_features = 75

# %%
# definenet
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(n_features, 128, cached=False) # if you defined cache=True, the shape of batch must be same!
        self.bn1 = BatchNorm1d(128)
        self.conv2 = GCNConv(128, 64, cached=False)
        self.bn2 = BatchNorm1d(64)
        self.fc1 = Linear(64, 64)
        self.bn3 = BatchNorm1d(64)
        self.fc2 = Linear(64, 64)
        self.fc3 = Linear(64, 3)
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = self.bn1(x)
        x = F.relu(self.conv2(x, edge_index))
        x = self.bn2(x)
        x = global_add_pool(x, data.batch)
        x = F.relu(self.fc1(x))
        x = self.bn3(x)
        x = F.relu(self.fc2(x))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.fc3(x)
        x = F.log_softmax(x, dim=1)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
#optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
print(model)
# Out:
# Net(
#   (conv1): GCNConv(75, 128)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): GCNConv(128, 64)
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=64, out_features=64, bias=True)
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
def train(epoch):
    model.train()
    loss_all = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_X)

# %%
def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data)
        pred = output.max(dim=1)[1]
        correct += pred.eq(data.y).sum().item()
    return correct / len(loader.dataset)

# %%
hist = {"loss":[], "acc":[], "test_acc":[]}
for epoch in range(1, 101):
    train_loss = train(epoch)
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    hist["loss"].append(train_loss)
    hist["acc"].append(train_acc)
    hist["test_acc"].append(test_acc)
    print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Train_acc: {train_acc:.3}, Test_acc: {test_acc:.3}')
# Out:
# Epoch: 1, Train loss: 0.833, Train_acc: 0.58, Test_acc: 0.611
# Epoch: 2, Train loss: 0.665, Train_acc: 0.663, Test_acc: 0.685
# Epoch: 3, Train loss: 0.547, Train_acc: 0.783, Test_acc: 0.767
# Epoch: 4, Train loss: 0.474, Train_acc: 0.774, Test_acc: 0.747
# Epoch: 5, Train loss: 0.458, Train_acc: 0.826, Test_acc: 0.79
# Epoch: 6, Train loss: 0.424, Train_acc: 0.825, Test_acc: 0.774
# Epoch: 7, Train loss: 0.408, Train_acc: 0.722, Test_acc: 0.677
# Epoch: 8, Train loss: 0.448, Train_acc: 0.84, Test_acc: 0.794
# Epoch: 9, Train loss: 0.377, Train_acc: 0.823, Test_acc: 0.798
# Epoch: 10, Train loss: 0.369, Train_acc: 0.858, Test_acc: 0.798
# Epoch: 11, Train loss: 0.388, Train_acc: 0.861, Test_acc: 0.813
# Epoch: 12, Train loss: 0.428, Train_acc: 0.812, Test_acc: 0.755
# Epoch: 13, Train loss: 0.4, Train_acc: 0.815, Test_acc: 0.786
# Epoch: 14, Train loss: 0.368, Train_acc: 0.822, Test_acc: 0.767
# Epoch: 15, Train loss: 0.339, Train_acc: 0.861, Test_acc: 0.786
# Epoch: 16, Train loss: 0.366, Train_acc: 0.825, Test_acc: 0.767
# Epoch: 17, Train loss: 0.322, Train_acc: 0.857, Test_acc: 0.79
# Epoch: 18, Train loss: 0.302, Train_acc: 0.854, Test_acc: 0.817
# Epoch: 19, Train loss: 0.352, Train_acc: 0.838, Test_acc: 0.782
# Epoch: 20, Train loss: 0.343, Train_acc: 0.878, Test_acc: 0.79
# Epoch: 21, Train loss: 0.328, Train_acc: 0.896, Test_acc: 0.813
# Epoch: 22, Train loss: 0.324, Train_acc: 0.874, Test_acc: 0.805
# Epoch: 23, Train loss: 0.293, Train_acc: 0.897, Test_acc: 0.79
# Epoch: 24, Train loss: 0.322, Train_acc: 0.885, Test_acc: 0.821
# Epoch: 25, Train loss: 0.326, Train_acc: 0.873, Test_acc: 0.77
# Epoch: 26, Train loss: 0.363, Train_acc: 0.884, Test_acc: 0.813
# Epoch: 27, Train loss: 0.286, Train_acc: 0.892, Test_acc: 0.767
# Epoch: 28, Train loss: 0.286, Train_acc: 0.904, Test_acc: 0.833
# Epoch: 29, Train loss: 0.314, Train_acc: 0.907, Test_acc: 0.79
# Epoch: 30, Train loss: 0.261, Train_acc: 0.91, Test_acc: 0.798
# Epoch: 31, Train loss: 0.271, Train_acc: 0.867, Test_acc: 0.817
# Epoch: 32, Train loss: 0.266, Train_acc: 0.924, Test_acc: 0.833
# Epoch: 33, Train loss: 0.255, Train_acc: 0.915, Test_acc: 0.802
# Epoch: 34, Train loss: 0.282, Train_acc: 0.85, Test_acc: 0.747
# Epoch: 35, Train loss: 0.368, Train_acc: 0.896, Test_acc: 0.833
# Epoch: 36, Train loss: 0.312, Train_acc: 0.876, Test_acc: 0.817
# Epoch: 37, Train loss: 0.285, Train_acc: 0.895, Test_acc: 0.809
# Epoch: 38, Train loss: 0.274, Train_acc: 0.906, Test_acc: 0.848
# Epoch: 39, Train loss: 0.281, Train_acc: 0.9, Test_acc: 0.809
# Epoch: 40, Train loss: 0.283, Train_acc: 0.915, Test_acc: 0.809
# Epoch: 41, Train loss: 0.248, Train_acc: 0.921, Test_acc: 0.821
# Epoch: 42, Train loss: 0.281, Train_acc: 0.932, Test_acc: 0.837
# Epoch: 43, Train loss: 0.242, Train_acc: 0.884, Test_acc: 0.774
# Epoch: 44, Train loss: 0.252, Train_acc: 0.875, Test_acc: 0.798
# Epoch: 45, Train loss: 0.251, Train_acc: 0.927, Test_acc: 0.821
# Epoch: 46, Train loss: 0.238, Train_acc: 0.915, Test_acc: 0.786
# Epoch: 47, Train loss: 0.266, Train_acc: 0.904, Test_acc: 0.802
# Epoch: 48, Train loss: 0.26, Train_acc: 0.721, Test_acc: 0.673
# Epoch: 49, Train loss: 0.51, Train_acc: 0.551, Test_acc: 0.525
# Epoch: 50, Train loss: 0.499, Train_acc: 0.789, Test_acc: 0.77
# Epoch: 51, Train loss: 0.431, Train_acc: 0.822, Test_acc: 0.805
# Epoch: 52, Train loss: 0.399, Train_acc: 0.81, Test_acc: 0.794
# Epoch: 53, Train loss: 0.404, Train_acc: 0.886, Test_acc: 0.829
# Epoch: 54, Train loss: 0.351, Train_acc: 0.839, Test_acc: 0.817
# Epoch: 55, Train loss: 0.33, Train_acc: 0.889, Test_acc: 0.829
# Epoch: 56, Train loss: 0.319, Train_acc: 0.906, Test_acc: 0.825
# Epoch: 57, Train loss: 0.272, Train_acc: 0.882, Test_acc: 0.837
# Epoch: 58, Train loss: 0.273, Train_acc: 0.901, Test_acc: 0.813
# Epoch: 59, Train loss: 0.296, Train_acc: 0.884, Test_acc: 0.77
# Epoch: 60, Train loss: 0.279, Train_acc: 0.916, Test_acc: 0.844
# Epoch: 61, Train loss: 0.287, Train_acc: 0.9, Test_acc: 0.844
# Epoch: 62, Train loss: 0.275, Train_acc: 0.907, Test_acc: 0.817
# Epoch: 63, Train loss: 0.272, Train_acc: 0.911, Test_acc: 0.802
# Epoch: 64, Train loss: 0.237, Train_acc: 0.901, Test_acc: 0.802
# Epoch: 65, Train loss: 0.24, Train_acc: 0.91, Test_acc: 0.813
# Epoch: 66, Train loss: 0.282, Train_acc: 0.871, Test_acc: 0.774
# Epoch: 67, Train loss: 0.257, Train_acc: 0.922, Test_acc: 0.829
# Epoch: 68, Train loss: 0.258, Train_acc: 0.889, Test_acc: 0.782
# Epoch: 69, Train loss: 0.241, Train_acc: 0.917, Test_acc: 0.813
# Epoch: 70, Train loss: 0.253, Train_acc: 0.912, Test_acc: 0.84
# Epoch: 71, Train loss: 0.276, Train_acc: 0.921, Test_acc: 0.817
# Epoch: 72, Train loss: 0.236, Train_acc: 0.92, Test_acc: 0.848
# Epoch: 73, Train loss: 0.291, Train_acc: 0.92, Test_acc: 0.802
# Epoch: 74, Train loss: 0.242, Train_acc: 0.94, Test_acc: 0.805
# Epoch: 75, Train loss: 0.283, Train_acc: 0.924, Test_acc: 0.821
# Epoch: 76, Train loss: 0.225, Train_acc: 0.93, Test_acc: 0.84
# Epoch: 77, Train loss: 0.23, Train_acc: 0.935, Test_acc: 0.833
# Epoch: 78, Train loss: 0.223, Train_acc: 0.914, Test_acc: 0.84
# Epoch: 79, Train loss: 0.209, Train_acc: 0.93, Test_acc: 0.813
# Epoch: 80, Train loss: 0.246, Train_acc: 0.929, Test_acc: 0.786
# Epoch: 81, Train loss: 0.214, Train_acc: 0.945, Test_acc: 0.844
# Epoch: 82, Train loss: 0.189, Train_acc: 0.951, Test_acc: 0.852
# Epoch: 83, Train loss: 0.213, Train_acc: 0.949, Test_acc: 0.844
# Epoch: 84, Train loss: 0.207, Train_acc: 0.924, Test_acc: 0.821
# Epoch: 85, Train loss: 0.188, Train_acc: 0.948, Test_acc: 0.833
# Epoch: 86, Train loss: 0.209, Train_acc: 0.95, Test_acc: 0.809
# Epoch: 87, Train loss: 0.206, Train_acc: 0.94, Test_acc: 0.802
# Epoch: 88, Train loss: 0.232, Train_acc: 0.936, Test_acc: 0.794
# Epoch: 89, Train loss: 0.19, Train_acc: 0.936, Test_acc: 0.825
# Epoch: 90, Train loss: 0.204, Train_acc: 0.942, Test_acc: 0.813
# Epoch: 91, Train loss: 0.265, Train_acc: 0.888, Test_acc: 0.798
# Epoch: 92, Train loss: 0.301, Train_acc: 0.841, Test_acc: 0.743
# Epoch: 93, Train loss: 0.263, Train_acc: 0.924, Test_acc: 0.821
# Epoch: 94, Train loss: 0.239, Train_acc: 0.932, Test_acc: 0.778
# Epoch: 95, Train loss: 0.244, Train_acc: 0.928, Test_acc: 0.809
# Epoch: 96, Train loss: 0.237, Train_acc: 0.94, Test_acc: 0.813
# Epoch: 97, Train loss: 0.256, Train_acc: 0.943, Test_acc: 0.821
# Epoch: 98, Train loss: 0.212, Train_acc: 0.946, Test_acc: 0.817
# Epoch: 99, Train loss: 0.225, Train_acc: 0.905, Test_acc: 0.802
# Epoch: 100, Train loss: 0.235, Train_acc: 0.922, Test_acc: 0.805

# %%
ax = plt.subplot(1,1,1)
ax.plot([e for e in range(1,101)], hist["loss"], label="train_loss")
ax.plot([e for e in range(1,101)], hist["acc"], label="train_acc")
ax.plot([e for e in range(1,101)], hist["test_acc"], label="test_loss")
plt.xlabel("epoch")
ax.legend()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
from rdkit.Chem import DataStructs

# %%
train_fps = [AllChem.GetMorganFingerprintAsBitVect(mol,2) for mol in train_mols]
test_fps =  [AllChem.GetMorganFingerprintAsBitVect(mol,2) for mol in test_mols]

# %%
train_X = []
for fp in train_fps:
    arr = np.zeros(0,)
    DataStructs.ConvertToNumpyArray(fp, arr)
    train_X.append(arr)
train_X = np.asarray(train_X)
train_Y = [sol_cls_dict[train_mols[i].GetProp('SOL_classification')] for i in range(len(train_mols))]

test_X = []
for fp in test_fps:
    arr = np.zeros(0,)
    DataStructs.ConvertToNumpyArray(fp, arr)
    test_X.append(arr)
test_X = np.asarray(test_X)
test_Y = [sol_cls_dict[test_mols[i].GetProp('SOL_classification')] for i in range(len(test_mols))]

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(train_X, train_Y)
# Out:
# /Users/iwatobipen/.pyenv/versions/anaconda3-5.1.0/envs/py36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
pred = rfc.predict(test_X)

# %%
print(classification_report(test_Y, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73       102
#            1       0.66      0.62      0.64       115
#            2       0.62      0.60      0.61        40
#
#    micro avg       0.67      0.67      0.67       257
#    macro avg       0.66      0.66      0.66       257
# weighted avg       0.67      0.67      0.67       257

# %%
print(accuracy_score(test_Y, pred))
# Out:
# 0.6731517509727627
